# %%
import numpy as np
import torch
import torch.nn as nn
from modules import *
from data import *
import matplotlib.pylab as plt

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_generator = GeneratorFromLorenzAttractor()

# %%
Nx = 2**4
Nw = 2**0
Ny = data_generator.Nx
Nlayer = 2
sbf = SinkBF_multilayers(Nx, Nw, Ny, Nlayer)

# %%
Nepoch = 2**6
Nbatch = 2**7
Nwup = 2**6
Nhrzn = 0
reg_param = 1.0

# %%
Nepoch = 2**6
Nbatch = 2**7
train_kalman_gain = True

if train_kalman_gain:
    Nwup = 2**6
    Nhrzn = 0
else:
    Nwup = 0
    Nhrzn = 2**6
reg_param = 1.0

for param in sbf.f_x_xw.parameters():
    param.requires_grad_(not train_kalman_gain)
for param in sbf.p_y_x.parameters():
    param.requires_grad_(not train_kalman_gain)
for param in sbf.q_x_y.parameters():
    param.requires_grad_(not train_kalman_gain)

# %%
optimizer = torch.optim.Adam(sbf.parameters())

# %%
loss_hist = []

# %%
run_training_004(sbf, data_generator, optimizer, Nepoch, Nbatch,
    Nwup, Nhrzn, reg_param, loss_hist = loss_hist, tol=1e-1, eps_given=1e-1, max_itr=2**10, rand = 'uniform')
pass
# Out:
# 0:08:02.655606 epoch 0025 loss 2.03e-01 resid 5.87e-03 dist 1.97e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-ef3bb06e4687> in <module>
#       1 run_training_004(sbf, data_generator, optimizer, Nepoch, Nbatch,
# ----> 2     Nwup, Nhrzn, reg_param, loss_hist = loss_hist, tol=1e-1, eps_given=1e-1, max_itr=2**10, rand = 'uniform')
#       3 pass
#
# ~\Documents\Python\20190605\modules.py in run_training_004(sbf_guass, data_generator, optimizer, Nepoch, Nbatch, Nwup, Nhrzn, reg_param, eps_given, tol, max_itr, loss_hist, rand)
#     590
#     591             sbf_guass.zero_grad()
# --> 592             _loss.backward()
#     593             optimizer.step()
#     594
#
# c:\users\shouta\appdata\local\programs\python\python36\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# c:\users\shouta\appdata\local\programs\python\python36\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
loss_hist_numpy = np.array(loss_hist)[:,1:].astype(np.float)

# %%
plt.plot(loss_hist_numpy[:,0], loss_hist_numpy[:,2], label = 'resid')
plt.plot(loss_hist_numpy[:,0], loss_hist_numpy[:,3], label = 'w-dist')
plt.legend()
plt.ylim([0,2])
plt.grid()
pass

# %% [markdown]
# ### test 001
# * train mode
# * Nwup = Nwup
# * Nhrzn = Nwup

# %%
Nhrzn_test = Nhrzn
Nwup_test = Nwup

# %%
sbf.train()
Ybatch = data_generator.batch(N=Nwup_test+1+Nhrzn_test, Nbatch=1) # (Nwup+1+Nhrzn, 1, Ny)
_, _W, _Yhat = sbf(torch.tensor(Ybatch[:Nwup_test+1,:]), Nhrzn_test)
W = _W.data.numpy() # (Nwup, 1, Nw)
Yhat = _Yhat.data.numpy() # (Nwup+1+Nhrzn, 1, Ny)

plt.figure(figsize=[36/2.57, 15/2.57])
plt.subplot(2,2,1)
plt.plot(Ybatch[:,0,0], '-', label = 'actual')
plt.plot(Yhat[:,0,0], '-', label = 'estimated')
plt.axvline(Nwup_test, color = 'k', linestyle = '--')
plt.legend()
plt.subplot(2,2,2)
plt.plot(W[:,0,:], '--x')
plt.subplot(2,2,3)
plt.hist(W[:,0,:])
plt.subplot(2,2,4)
plt.plot(W[:-1,0,0], W[1:,0,0],'-x')
pass

# %% [markdown]
# ### test 002
# * train mode
# * Nwup = 0
# * Nhrzn = Nwup

# %%
Nhrzn_test = Nwup
Nwup_test = 0

# %%
sbf.train()
Ybatch = data_generator.batch(N=Nwup_test+1+Nhrzn_test, Nbatch=1) # (Nwup+1+Nhrzn, 1, Ny)
_, _W, _Yhat = sbf(torch.tensor(Ybatch[:Nwup_test+1,:]), Nhrzn_test)
W = _W.data.numpy() # (Nwup, 1, Nw)
Yhat = _Yhat.data.numpy() # (Nwup+1+Nhrzn, 1, Ny)

# %%
plt.figure()
plt.plot(Ybatch[:,0,0], '-x', label = 'actual')
plt.plot(Yhat[:,0,0], '-x', label = 'estimated')
plt.axvline(Nwup_test, color = 'k', linestyle = '--')

# %% [markdown]
# ### test 003
# * eval model
# * Nwup = 0
# * Nhrzn = Nwup

# %%
Nhrzn_test = Nwup
Nwup_test = 0
Nbatch_test = 2**1

# %%
Ybatch = data_generator.batch(N=Nwup_test+1+Nhrzn_test, Nbatch=1) # (Nwup+1+Nhrzn, 1, Ny)
Ybatch = np.repeat(Ybatch, Nbatch_test, axis=1)

# %%
sbf.eval()
_, _W, _Yhat = sbf(torch.tensor(Ybatch[:Nwup_test+1,:]), Nhrzn_test)
W = _W.data.numpy() # (Nwup, *, Nw)
Yhat = _Yhat.data.numpy() # (Nwup+1+Nhrzn, *, Ny)

plt.figure(figsize=[40/2.57, 12/2.57])
plt.plot(Ybatch[:,0,0], '-k', label = 'actual')
plt.plot(Yhat[:,:,0], '--')
plt.axvline(Nwup_test, color = 'k', linestyle = '--')
plt.ylim([-2,2])
plt.legend()
plt.figure()
plt.plot(Yhat[:,0,0], Yhat[:,0,1])
plt.plot(Ybatch[:,0,0], Ybatch[:,0,1])

# %% [markdown]
# ### test 004
# * train mode
# * Nwup = Nwup
# * Nhrzn = 0
#
# cumsum(W) ~ brownian motion?

# %%
Nhrzn_test = 0
Nwup_test = Nwup
Nbatch_test = 2**7

# %%
sbf.train()
Ybatch = data_generator.batch(N=Nwup_test+1+Nhrzn_test, Nbatch=Nbatch_test) # (Nwup+1+Nhrzn, 1, Ny)
_, _W, _ = sbf(torch.tensor(Ybatch[:Nwup_test+1,:]), Nhrzn_test)
W = _W.data.numpy() # (Nwup, *, Nw)

# %%
W_cumsum = np.cumsum(W, axis=0)
var_W_cumsum = np.std(W_cumsum, axis=1)**2 # (Nwup, Nw)

# %%
plt.figure(figsize=[40/2.57, 12/2.57])
plt.subplot(1,2,1)
plt.hist(W_cumsum[-1,:,0])
plt.subplot(1,2,2)
plt.plot(var_W_cumsum, 'x')
plt.plot(np.arange(Nwup_test))

# %%
plt.hist(W[-1,:,0])
# Out:
# (array([ 8.,  9.,  9., 21., 19., 32., 15.,  5.,  7.,  3.]),
#  array([-1.6899467 , -1.3219016 , -0.9538566 , -0.5858115 , -0.21776648,
#          0.15027857,  0.5183236 ,  0.88636863,  1.2544137 ,  1.6224587 ,
#          1.9905038 ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
jkkkkkk
